# %%
from box import ConfigBox

# %% [markdown]
# ## Download data from Google Drive

# %%
import gdown

# %%
URL="https://drive.google.com/file/d/1ii_S5SGFQnTOnaXv5ApIY0X9BtE0RLcs/view?usp=sharing"

# %%
FILE_ID = URL.split("/")[-2]

# %%
prefix = "https://drive.google.com/uc?/export=download&id="

gdown.download(prefix + FILE_ID, "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1ii_S5SGFQnTOnaXv5ApIY0X9BtE0RLcs
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1ii_S5SGFQnTOnaXv5ApIY0X9BtE0RLcs&confirm=t&uuid=fda83261-43f6-4cc6-901e-a5bbfd5b2466
# To: /Users/sametkoleoglu/ArtificalIntelligence/DeepLearnig/Kidney-Disease-Classification/research/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip
# 100%|██████████| 1.63G/1.63G [02:10<00:00, 12.5MB/s]
# 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip'
